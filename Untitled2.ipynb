# %% [markdown]
# <a href="https://colab.research.google.com/github/irina-S123/-3/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('https://gbcdn.mrgcdn.ru/uploads/asset/5291776/attachment/817da6a75fe672f89064b6f2bb241a22.csv', sep= ';', encoding='cp1251')

df
# Out:
#                          Субъект РФ  \
# 0              Российская Федерация
# 1     Центральный федеральный округ
# 2              Белгородская область
# 3                  Брянская область
# 4              Владимирская область
# ..                              ...
# 89                 Амурская область
# 90              Магаданская область
# 91              Сахалинская область
# 92     Еврейская автономная область
# 93       Чукотский автономный округ
#
#     Численность студентов, всего человек, 2015  \
# 0                                      4766479
# 1                                      1455273
# 2                                        53050
# 3                                        34540
# 4                                        33461
# ..                                         ...
# 89                                       19361
# 90                                        4451
# 91                                        8889
# ...

# %%
df = pd.DataFrame(df, columns = ['Субъект РФ', 'Численность студентов заочная форма, человек, 2019'])
df
# Out:
#                          Субъект РФ  \
# 0              Российская Федерация
# 1     Центральный федеральный округ
# 2              Белгородская область
# 3                  Брянская область
# 4              Владимирская область
# ..                              ...
# 89                 Амурская область
# 90              Магаданская область
# 91              Сахалинская область
# 92     Еврейская автономная область
# 93       Чукотский автономный округ
#
#     Численность студентов заочная форма, человек, 2019
# 0                                             1500272
# 1                                              422616
# 2                                               22570
# 3                                               11641
# 4                                               13224
# ..                                                ...
# 89                                               5374
# 90                                               1531
# ...

# %%
df = df[df['Численность студентов заочная форма, человек, 2019'] <= 10000]
df
# Out:
#                                 Субъект РФ  \
# 6                       Ивановская область
# 7                        Калужская область
# 8                      Костромская область
# 10                        Липецкая область
# 14                      Смоленская область
# 16                        Тверская область
# 21                      Республика Карелия
# 22                         Республика Коми
# 23                   Архангельская область
# 24                     Вологодская область
# 25                 Калининградская область
# 26                   Ленинградская область
# 27                      Мурманская область
# 28                    Новгородская область
# 29                       Псковская область
# 31               Ненецкий автономный округ
# 33                       Республика Адыгея
# 34                     Республика Калмыкия
# 39                           г.Севастополь
# 43                    Республика Ингушетия
# 44         Кабардино-Балкарская Республика
# ...

# %%
plot = sns.barplot(df, x = 'Субъект РФ', y = 'Численность студентов заочная форма, человек, 2019')
plot.set_xticklabels(labels = df['Субъект РФ'], rotation = 90)
# Out:
# [Text(0, 0, '   Ивановская область'),
#  Text(1, 0, '   Калужская область'),
#  Text(2, 0, '   Костромская область'),
#  Text(3, 0, '   Липецкая область'),
#  Text(4, 0, '   Смоленская область'),
#  Text(5, 0, '   Тверская область'),
#  Text(6, 0, '   Республика Карелия'),
#  Text(7, 0, '   Республика Коми'),
#  Text(8, 0, '   Архангельская область'),
#  Text(9, 0, '   Вологодская область'),
#  Text(10, 0, '   Калининградская область'),
#  Text(11, 0, '   Ленинградская область'),
#  Text(12, 0, '   Мурманская область'),
#  Text(13, 0, '   Новгородская область'),
#  Text(14, 0, '   Псковская область'),
#  Text(15, 0, '   Ненецкий автономный округ'),
#  Text(16, 0, '   Республика Адыгея'),
#  Text(17, 0, '   Республика Калмыкия'),
#  Text(18, 0, '   г.Севастополь'),
#  Text(19, 0, '   Республика Ингушетия'),
#  Text(20, 0, '   Кабардино-Балкарская Республика'),
#  Text(21, 0, '   Карачаево-Черкесская Республика'),
#  Text(22, 0, '   Республика Северная Осетия - Алания'),
# ...
