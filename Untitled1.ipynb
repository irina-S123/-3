# %% [markdown]
# <a href="https://colab.research.google.com/github/irina-S123/-3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('https://gbcdn.mrgcdn.ru/uploads/asset/5291776/attachment/817da6a75fe672f89064b6f2bb241a22.csv', sep= ';', encoding='cp1251')

df
# Out:
#                          Субъект РФ  \
# 0              Российская Федерация
# 1     Центральный федеральный округ
# 2              Белгородская область
# 3                  Брянская область
# 4              Владимирская область
# ..                              ...
# 89                 Амурская область
# 90              Магаданская область
# 91              Сахалинская область
# 92     Еврейская автономная область
# 93       Чукотский автономный округ
#
#     Численность студентов, всего человек, 2015  \
# 0                                      4766479
# 1                                      1455273
# 2                                        53050
# 3                                        34540
# 4                                        33461
# ..                                         ...
# 89                                       19361
# 90                                        4451
# 91                                        8889
# ...

# %%
df = pd.DataFrame(df, columns = ['Субъект РФ', 'Численность студентов, очная форма, человек, 2017'])
df
# Out:
#                          Субъект РФ  \
# 0              Российская Федерация
# 1     Центральный федеральный округ
# 2              Белгородская область
# 3                  Брянская область
# 4              Владимирская область
# ..                              ...
# 89                 Амурская область
# 90              Магаданская область
# 91              Сахалинская область
# 92     Еврейская автономная область
# 93       Чукотский автономный округ
#
#     Численность студентов, очная форма, человек, 2017
# 0                                             2380454
# 1                                              744398
# 2                                               23192
# 3                                               11910
# 4                                               12358
# ..                                                ...
# 89                                               9616
# 90                                               1111
# ...

# %%
msk = df['Субъект РФ'].str.contains('округ')
df[msk]
# Out:
#                               Субъект РФ  \
# 1          Центральный федеральный округ
# 20     Северо-Западный федеральный округ
# 31             Ненецкий автономный округ
# 32               Южный федеральный округ
# 41   Северо-Кавказский федеральный округ
# 49         Приволжский федеральный округ
# 64           Уральский федеральный округ
# 69     Ханты-Мансийский автономный округ
# 70       Ямало-Ненецкий автономный округ
# 71           Сибирский федеральный округ
# 82     Дальневосточный федеральный округ
# 93            Чукотский автономный округ
#
#     Численность студентов, очная форма, человек, 2017
# 1                                              744398
# 20                                             274309
# 31                                                  0
# 32                                             224305
# 41                                             107650
# 49                                             456417
# ...

# %%
df = df.loc[33:40]
df
# Out:
#                   Субъект РФ  \
# 33         Республика Адыгея
# 34       Республика Калмыкия
# 35        Краснодарский край
# 36      Астраханская область
# 37     Волгоградская область
# 38        Ростовская область
# 39             г.Севастополь
# 40           Республика Крым
#
#     Численность студентов, очная форма, человек, 2017
# 33                                               7006
# 34                                               4548
# 35                                              58855
# 36                                              16685
# 37                                              33513
# 38                                              69521
# 39                                               8627
# 40                                              25550

# %%
plot_1 = sns.barplot(df, x = 'Субъект РФ', y = 'Численность студентов, очная форма, человек, 2017')
plot_1.set_xticklabels(labels = df['Субъект РФ'], rotation = 90)
# Out:
# [Text(0, 0, '   Республика Адыгея'),
#  Text(1, 0, '   Республика Калмыкия'),
#  Text(2, 0, '   Краснодарский край'),
#  Text(3, 0, '   Астраханская область'),
#  Text(4, 0, '   Волгоградская область'),
#  Text(5, 0, '   Ростовская область'),
#  Text(6, 0, '   г.Севастополь'),
#  Text(7, 0, '   Республика Крым')]
